# %%
import fastf1 as ff

# %%
session = ff.get_session(2022, 1, "R")

# %%
from google.cloud import storage

# %%
client = storage.Client()

# %%
b = client.get_bucket('f1dashboard')

# %%
for b in b.list_blobs():
    print(b)
# Out:
# <Blob: f1dashboard, 1900/, 1719535435064134>
# <Blob: f1dashboard, 2019/2019-03-17_Australian_Grand_Prix/2019-03-17_Race/_extended_timing_data.ff1pkl, 1719613394335438>
# <Blob: f1dashboard, 2019/2019-03-17_Australian_Grand_Prix/2019-03-17_Race/car_data.ff1pkl, 1719613394863912>
# <Blob: f1dashboard, 2019/2019-03-17_Australian_Grand_Prix/2019-03-17_Race/driver_info.ff1pkl, 1719613394254335>
# <Blob: f1dashboard, 2019/2019-03-17_Australian_Grand_Prix/2019-03-17_Race/lap_count.ff1pkl, 1719613394278638>
# <Blob: f1dashboard, 2019/2019-03-17_Australian_Grand_Prix/2019-03-17_Race/position_data.ff1pkl, 1719613394827315>
# <Blob: f1dashboard, 2019/2019-03-17_Australian_Grand_Prix/2019-03-17_Race/race_control_messages.ff1pkl, 1719613394261473>
# <Blob: f1dashboard, 2019/2019-03-17_Australian_Grand_Prix/2019-03-17_Race/session_info.ff1pkl, 1719613394208858>
# <Blob: f1dashboard, 2019/2019-03-17_Australian_Grand_Prix/2019-03-17_Race/session_status_data.ff1pkl, 1719613394131367>
# ...
